# %% [markdown]
# <a href="https://colab.research.google.com/github/shreesalkani/mini-project/blob/main/processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize

# %%
img=imread('/content/drive/MyDrive/Vehicle/buses/hobi-industri-C-zgN_LEKb8-unsplash.jpg')
plt.imshow(img)

# %%
img.shape
# Out:
# (3985, 5977, 3)

# %%
import os
import numpy as np

from skimage.io import imread

datadir = '/content/drive/MyDrive/Vehicle'

categories = ['buses','trucks']
target = []
flat_data = []

for i in categories:
  path = os.path.join(datadir,i)
  #print(path)
  for img in os.listdir(path):
    img_array = imread(os.path.join(path,img))
    #plt.imshow(img_array)  
    #plt.show()
    img_resize = resize(img_array,(150,150,3))
    flat_data.append(np.ndarray.flatten(img_resize))
    target.append(i)

flat_data = np.array(flat_data)
target = np.array(target)

# %%
df = pd.DataFrame(flat_data)
df['Target'] = target
df.head()
# Out:
#           0         1         2         3  ...     67497     67498     67499  Target
# 0  0.337255  0.572549  0.674510  0.349020  ...  0.023529  0.043137  0.047059   buses
# 1  0.729412  0.580882  0.400000  0.698889  ...  0.533333  0.619608  0.776471   buses
# 2  0.835294  0.886275  0.905882  0.835294  ...  0.166119  0.184314  0.197492   buses
# 3  0.788170  0.760784  0.745098  0.784314  ...  0.725556  0.717712  0.705882   buses
# 4  0.686275  0.752941  0.815686  0.674510  ...  0.394170  0.402915  0.371542  trucks
#
# [5 rows x 67501 columns]
